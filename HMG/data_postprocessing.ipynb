# %% [markdown]
# # SPIEC-EASI Data Post-Processing

# %% [markdown]
# Author: Lei Mao <br>
# Date: 3/13/2017

# %% [markdown]
# Using the weights data and taxonomy annotation from [SPIEC-EASI](https://github.com/zdk123/SpiecEasi), this script is able to prepare the data for microbial network inference plot. The data for the plot contains the table of positive edge fractions and the table of edge pair numbers. The default analysis is at "Order" level. Analysis at deeper levels, such as "Family" and "Genus" may have problems due to "NA" in some OTUs.

# %%
import pandas as pd

# %%
weights_file = 'weights.csv'
taxonomy_file = 'tax_table.csv'
analysis_level = 'Order'

# %%
def index_transform(weights):
    '''
    Transform 1-based indices in the weights dataframe to 0-based indices.
    weights: weights dataframe
    '''
    weights_transformed = weights.copy()
    weights_transformed['i'] = weights_transformed['i'].apply(lambda x: x - 1)
    weights_transformed['j'] = weights_transformed['j'].apply(lambda x: x - 1)
    return weights_transformed

# %%
def taxonomy_annotate(weights, taxonomy, level):
    '''
    Add taxonomy annotations of certain level to the weights dataframe using the indices.
    weights: weights dataframe
    taxonomy: taxonomy dataframe
    level: level name
    '''
    weights_added = weights.copy()
    weights_added['tax_1'] = weights_added['i'].apply(lambda x: taxonomy.iloc[x][level])
    weights_added['tax_2'] = weights_added['j'].apply(lambda x: taxonomy.iloc[x][level])
    return weights_added

# %%
def edge_count(weights, tax_1, tax_2):
    '''
    Count and calculate the positive propotions of certain taxonomy pair (tax_1 and tax_2).
    weights: weights dataframe
    tax_1: taxonomy name 1
    tax_2: taxonomy name 2
    Return: association, number of edges
    '''
    weights_interest = weights[((weights['tax_1'] == tax_1) & (weights['tax_2'] == tax_2)) | ((weights['tax_1'] == tax_2) & (weights['tax_2'] == tax_1))]
    num_positive = len(weights_interest[weights_interest['x'] > 0])
    num_negative = len(weights_interest[weights_interest['x'] < 0])
    if len(weights_interest) > 0:
        return (float(num_positive) / len(weights_interest), len(weights_interest))
    else:
        return ('NaN', 0)

# %%
def network_inference(weights, taxonomy, level):
    '''
    Prepare network inference table for analysis and plot.
    weights: weights dataframe
    taxonomy: taxonomy dataframe
    level: level name
    '''
    weights_annotated = taxonomy_annotate(weights = weights, taxonomy = taxonomy, level = level)
    tax_list = taxonomy[level].unique().tolist()
    network = pd.DataFrame(index = tax_list, columns = tax_list)
    num_edge = pd.DataFrame(index = tax_list, columns = tax_list)
    for tax_1 in tax_list:
        for tax_2 in tax_list:
            count = edge_count(weights = weights_annotated, tax_1 = tax_1, tax_2= tax_2)
            network.ix[tax_1][tax_2] = count[0]
            num_edge.ix[tax_1][tax_2] = count[1]
    return network, num_edge

# %%
weights = pd.read_csv(weights_file, sep=',')
weights = index_transform(weights)

# %%
weights.head()
# Out:
#    i   j         x
# 0  2   7  0.244049
# 1  3  10  0.294267
# 2  2  14  0.106800
# 3  0  18  0.032778
# 4  5  18  0.035493

# %%
tax = pd.read_csv(taxonomy_file, sep=',')

# %%
tax.head()
# Out:
#     Kingdom         Phylum        Class          Order                 Family  \
# 0  Bacteria     Firmicutes   Clostridia  Clostridiales        Lachnospiraceae
# 1  Bacteria     Firmicutes   Clostridia  Clostridiales  Peptostreptococcaceae
# 2  Bacteria  Bacteroidetes  Bacteroidia  Bacteroidales         Bacteroidaceae
# 3  Bacteria  Bacteroidetes  Bacteroidia  Bacteroidales         Bacteroidaceae
# 4  Bacteria  Bacteroidetes  Bacteroidia  Bacteroidales         Bacteroidaceae
#
#          Genus Species
# 0        Dorea     NaN
# 1          NaN     NaN
# 2  Bacteroides     NaN
# 3  Bacteroides     NaN
# 4  Bacteroides     NaN

# %%
network, num_edge = network_inference(weights = weights, taxonomy = tax, level = analysis_level)

# %%
network
# Out:
#                    Clostridiales Bacteroidales Enterobacteriales Bacillales  \
# Clostridiales           0.857143      0.105263               NaN        NaN
# Bacteroidales           0.105263      0.971429               NaN        NaN
# Enterobacteriales            NaN           NaN                 1          1
# Bacillales                   NaN           NaN                 1        NaN
# Lactobacillales                0             0                 1          1
# Pasteurellales               NaN           NaN               NaN        NaN
# Burkholderiales              NaN           NaN               NaN        NaN
# Erysipelotrichales      0.857143           NaN               NaN        NaN
# Bifidobacteriales            NaN           NaN               NaN        NaN
# Desulfovibrionales           NaN           NaN               NaN        NaN
# Coriobacteriales             NaN           NaN               NaN        NaN
#
#                    Lactobacillales Pasteurellales Burkholderiales  \
# Clostridiales                    0            NaN             NaN
# Bacteroidales                    0            NaN             NaN
# Enterobacteriales                1            NaN             NaN
# Bacillales                       1            NaN             NaN
# Lactobacillales                  1              1             NaN
# Pasteurellales                   1            NaN             NaN
# Burkholderiales                NaN            NaN             NaN
# Erysipelotrichales             NaN            NaN             NaN
# Bifidobacteriales              NaN            NaN             NaN
# Desulfovibrionales             NaN            NaN             NaN
# Coriobacteriales               NaN            NaN             NaN
#
#                    Erysipelotrichales Bifidobacteriales Desulfovibrionales  \
# Clostridiales                0.857143               NaN                NaN
# Bacteroidales                     NaN               NaN                NaN
# Enterobacteriales                 NaN               NaN                NaN
# Bacillales                        NaN               NaN                NaN
# Lactobacillales                   NaN               NaN                NaN
# Pasteurellales                    NaN               NaN                NaN
# Burkholderiales                   NaN               NaN                NaN
# Erysipelotrichales                NaN               NaN                NaN
# Bifidobacteriales                 NaN               NaN                NaN
# Desulfovibrionales                NaN               NaN                NaN
# Coriobacteriales                  NaN               NaN                NaN
#
#                    Coriobacteriales
# Clostridiales                   NaN
# Bacteroidales                   NaN
# Enterobacteriales               NaN
# Bacillales                      NaN
# Lactobacillales                 NaN
# Pasteurellales                  NaN
# Burkholderiales                 NaN
# Erysipelotrichales              NaN
# Bifidobacteriales               NaN
# Desulfovibrionales              NaN
# Coriobacteriales                NaN

# %%
num_edge
# Out:
#                    Clostridiales Bacteroidales Enterobacteriales Bacillales  \
# Clostridiales                105            19                 0          0
# Bacteroidales                 19            35                 0          0
# Enterobacteriales              0             0                 6          4
# Bacillales                     0             0                 4          0
# Lactobacillales                4             2                 1          2
# Pasteurellales                 0             0                 0          0
# Burkholderiales                0             0                 0          0
# Erysipelotrichales             7             0                 0          0
# Bifidobacteriales              0             0                 0          0
# Desulfovibrionales             0             0                 0          0
# Coriobacteriales               0             0                 0          0
#
#                    Lactobacillales Pasteurellales Burkholderiales  \
# Clostridiales                    4              0               0
# Bacteroidales                    2              0               0
# Enterobacteriales                1              0               0
# Bacillales                       2              0               0
# Lactobacillales                  3              2               0
# Pasteurellales                   2              0               0
# Burkholderiales                  0              0               0
# Erysipelotrichales               0              0               0
# Bifidobacteriales                0              0               0
# Desulfovibrionales               0              0               0
# Coriobacteriales                 0              0               0
#
#                    Erysipelotrichales Bifidobacteriales Desulfovibrionales  \
# Clostridiales                       7                 0                  0
# Bacteroidales                       0                 0                  0
# Enterobacteriales                   0                 0                  0
# Bacillales                          0                 0                  0
# Lactobacillales                     0                 0                  0
# Pasteurellales                      0                 0                  0
# Burkholderiales                     0                 0                  0
# Erysipelotrichales                  0                 0                  0
# Bifidobacteriales                   0                 0                  0
# Desulfovibrionales                  0                 0                  0
# Coriobacteriales                    0                 0                  0
#
#                    Coriobacteriales
# Clostridiales                     0
# Bacteroidales                     0
# Enterobacteriales                 0
# Bacillales                        0
# Lactobacillales                   0
# Pasteurellales                    0
# Burkholderiales                   0
# Erysipelotrichales                0
# Bifidobacteriales                 0
# Desulfovibrionales                0
# Coriobacteriales                  0

# %%
network.to_csv('network_' + analysis_level + '.csv')

# %%
num_edge.to_csv('num_edge_' + analysis_level + '.csv')
